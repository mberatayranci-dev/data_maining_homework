# %% [markdown]
# <a href="https://colab.research.google.com/github/mberatayranci-dev/data_maining_homework/blob/main/hw1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
ogrenci_verileri = {
    'Oğrenci': ['Muhammed', 'Berat', 'Ayranci'],
    'Notu': [80, 95, 100]
}
tablo = pd.DataFrame(ogrenci_verileri)
ortalama = tablo['Notu'].mean()

print("\nSınıfın Not Ortalaması:", ortalama)
# Out:
# Sınıfın Not Ortalaması: 91.66666666666667
